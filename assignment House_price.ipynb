# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Vilas\Untitled Folder\House_price.csv")
df
# Out:
#         Id  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710     Attchd         548     208500
# ...

# %%
df.describe()
# Out:
#                 Id  LotFrontage        LotArea   MasVnrArea     1stFlrSF  \
# count  1460.000000  1201.000000    1460.000000  1452.000000  1460.000000
# mean    730.500000    70.049958   10516.828082   103.685262  1162.626712
# std     421.610009    24.284752    9981.264932   181.066207   386.587738
# min       1.000000    21.000000    1300.000000     0.000000   334.000000
# 25%     365.750000    59.000000    7553.500000     0.000000   882.000000
# 50%     730.500000    69.000000    9478.500000     0.000000  1087.000000
# 75%    1095.250000    80.000000   11601.500000   166.000000  1391.250000
# max    1460.000000   313.000000  215245.000000  1600.000000  4692.000000
#
#           2ndFlrSF    GrLivArea   GarageArea      SalePrice
# count  1460.000000  1460.000000  1460.000000    1460.000000
# mean    346.992466  1515.463699   472.980137  180921.195890
# std     436.528436   525.480383   213.804841   79442.502883
# min       0.000000   334.000000     0.000000   34900.000000
# ...

# %%
df.isnull().sum()
# Out:
# Id                0
# LotFrontage     259
# LotArea           0
# Alley          1369
# MasVnrArea        8
# 1stFlrSF          0
# 2ndFlrSF          0
# GrLivArea         0
# GarageType       81
# GarageArea        0
# SalePrice         0
# dtype: int64

# %%
df['LotFrontage'].mean()
# Out:
# 70.04995836802665

# %%
df['GarageType']=df['GarageType'].map({'Attchd':1,'Detchd':2})
df
# Out:
#         Id  LotFrontage  LotArea Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450   NaN       196.0       856       854
# 1        2         80.0     9600   NaN         0.0      1262         0
# 2        3         68.0    11250   NaN       162.0       920       866
# 3        4         60.0     9550   NaN         0.0       961       756
# 4        5         84.0    14260   NaN       350.0      1145      1053
# ...    ...          ...      ...   ...         ...       ...       ...
# 1455  1456         62.0     7917   NaN         0.0       953       694
# 1456  1457         85.0    13175   NaN       119.0      2073         0
# 1457  1458         66.0     9042   NaN         0.0      1188      1152
# 1458  1459         68.0     9717   NaN         0.0      1078         0
# 1459  1460         75.0     9937   NaN         0.0      1256         0
#
#       GrLivArea  GarageType  GarageArea  SalePrice
# 0          1710         1.0         548     208500
# ...

# %%
df.GarageType.unique()
# Out:
# array([ 1.,  2., nan])

# %%
df.Alley.unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df['Alley']=df['Alley'].map({'Grvl':1,'Pave':2})
df
# Out:
#         Id  LotFrontage  LotArea  Alley  MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1         65.0     8450    NaN       196.0       856       854
# 1        2         80.0     9600    NaN         0.0      1262         0
# 2        3         68.0    11250    NaN       162.0       920       866
# 3        4         60.0     9550    NaN         0.0       961       756
# 4        5         84.0    14260    NaN       350.0      1145      1053
# ...    ...          ...      ...    ...         ...       ...       ...
# 1455  1456         62.0     7917    NaN         0.0       953       694
# 1456  1457         85.0    13175    NaN       119.0      2073         0
# 1457  1458         66.0     9042    NaN         0.0      1188      1152
# 1458  1459         68.0     9717    NaN         0.0      1078         0
# 1459  1460         75.0     9937    NaN         0.0      1256         0
#
#       GrLivArea  GarageType  GarageArea  SalePrice
# 0          1710         1.0         548     208500
# ...

# %%
df.Alley.unique()
# Out:
# array([nan,  1.,  2.])

# %%
df.isnull().sum()
# Out:
# Id                0
# LotFrontage     259
# LotArea           0
# Alley          1369
# MasVnrArea        8
# 1stFlrSF          0
# 2ndFlrSF          0
# GrLivArea         0
# GarageType      203
# GarageArea        0
# SalePrice         0
# dtype: int64

# %%
df.LotFrontage.unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
df=df.fillna("70")
df
# Out:
#         Id LotFrontage  LotArea Alley MasVnrArea  1stFlrSF  2ndFlrSF  \
# 0        1          65     8450    70        196       856       854
# 1        2          80     9600    70          0      1262         0
# 2        3          68    11250    70        162       920       866
# 3        4          60     9550    70          0       961       756
# 4        5          84    14260    70        350      1145      1053
# ...    ...         ...      ...   ...        ...       ...       ...
# 1455  1456          62     7917    70          0       953       694
# 1456  1457          85    13175    70        119      2073         0
# 1457  1458          66     9042    70          0      1188      1152
# 1458  1459          68     9717    70          0      1078         0
# 1459  1460          75     9937    70          0      1256         0
#
#       GrLivArea GarageType  GarageArea  SalePrice
# 0          1710          1         548     208500
# ...

# %%
df.isnull().sum()
# Out:
# Id             0
# LotFrontage    0
# LotArea        0
# Alley          0
# MasVnrArea     0
# 1stFlrSF       0
# 2ndFlrSF       0
# GrLivArea      0
# GarageType     0
# GarageArea     0
# SalePrice      0
# dtype: int64

# %%
sns.set(color_codes=True)

# %%
sns.barplot(df['LotArea'],df['SalePrice'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.displot(df['GrLivArea'])

# %%
sns.jointplot(df['1stFlrSF'],df['2ndFlrSF'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot(x="GrLivArea",y="SalePrice",data=df)
